# %% [markdown]
# # Job Data Analysis

# %%
import gspread
from gspread_dataframe import set_with_dataframe
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import nltk
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import string
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/daikiminaki/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#
gc = gspread.service_account(filename='datarebel-6576298f20fd.json')

def get_sheet_data(sheet, sheetname):
    # Open our new sheet and add some data.
    sh = gc.open(sheet)

    # Look at Item Sales Sheet
    sheet = sh.worksheet(sheetname)

    # Clean Item Sales DataFrame
    data = pd.DataFrame(sheet.get_all_values())

    try:
        if(data.shape[0] > 0):    
            data.columns = data.iloc[0] # Set Column
            data = data.iloc[1:]# Reset Table
            return data
    except:
        return data

def update_sheet(sheet, sheetname, dataset):
    # Get Current Data
    sheet_data = get_sheet_data(sheet, sheetname)

    # Combine with existing data
    dataset = pd.concat([sheet_data, dataset]).reset_index(drop=[1])

    # Look at Sheet
    sh = gc.open(sheet)
    worksheet = sh.worksheet(sheetname)
    set_with_dataframe(worksheet, dataset)

# %% [markdown]
# # Import Data

# %%
# Sheet and Worksheet Name
sheet = 'GlassDoorScraping - Data Analytics'
sheetname = 'Data'

job_df = get_sheet_data(sheet, sheetname)

# %%
job_df.head()
# Out:
# 0                           company_name  \
# 1                              AlohaCare
# 2                              Sidekicks
# 3  Metropolitan Transportation Authority
# 4                                  Uline
# 5                       Cleveland-Cliffs
#
# 0                                         job_title  \
# 1                                      Data Analyst
# 2           Board Certified Behavior Analyst (BCBA)
# 3  Cybersecurity Analyst Levels 1-7, Data Scientist
# 4                  Associate eCommerce Data Analyst
# 5              Procurement Analyst - Plant Services
#
# 0                                           job_link              location  \
# 1  https://www.glassdoor.com/partner/jobListing.h...          Honolulu, HI
# 2  https://www.glassdoor.com/partner/jobListing.h...  Township of Hamilton
# 3  https://www.glassdoor.com/partner/jobListing.h...             Manhattan
# 4  https://www.glassdoor.com/partner/jobListing.h...  Pleasant Prairie, WI
# 5  https://www.glassdoor.com/partner/jobListing.h...      West Chester, OH
#
# 0                      salary_est  \
# 1     $50K - $64K (Employer est.)
# 2  $95.00 Per Hour(Employer est.)
# 3
# 4    $61K - $89K (Glassdoor est.)
# 5    $62K - $87K (Glassdoor est.)
#
# 0                                  short_description  \
# 1  Sciences, data analysis, accounting or related...
# 2  Conduct re-assessments and develop plans that ...
# 3  Provides guidance and technical coaching to le...
# 4  Bachelor's degree in Marketing, Information Sy...
# 5  To evaluate alternative sourcing strategies Mi...
#
# 0                                       company_logo  \
# 1  https://media.glassdoor.com/sql/266409/alohaca...
# 2
# 3  https://media.glassdoor.com/sql/366592/mta-met...
# 4  https://media.glassdoor.com/sql/26828/uline-sq...
# 5  https://media.glassdoor.com/sql/157/cleveland-...
#
# 0                                     company_banner  \
# 1          /static/img/banners/default-ei-banner.jpg
# 2          /static/img/banners/default-ei-banner.jpg
# 3          /static/img/banners/default-ei-banner.jpg
# 4  https://media.glassdoor.com/banner/bh/26828/ul...
# 5  https://media.glassdoor.com/banner/bh/157/clev...
#
# 0                                       company_link  \
# 1  https://www.glassdoor.com/Overview/Working-at-...
# 2
# 3  https://www.glassdoor.com/Overview/Working-at-...
# 4  https://www.glassdoor.com/Overview/Working-at-...
# 5  https://www.glassdoor.com/Overview/Working-at-...
#
# 0                                        description         job_id  \
# 1  The Company:\nAlohaCare is a local, non-profit...  1008415699298
# 2  Looking to grow with an organization and be a ...
# 3  Job Information\n\n\nJob Title: Cybersecurity ...  1008359249694
# 4  Associate eCommerce Data Analyst\nCorporate He...  1008314527886
# 5  Cleveland-Cliffs has an immediate opening for ...  1008429169476
#
# 0                                       external_url  \
# 1  https://www.glassdoor.com/partner/jobListing.h...
# 2
# 3  https://www.glassdoor.com/partner/jobListing.h...
# 4  https://www.glassdoor.com/partner/jobListing.h...
# 5  https://www.glassdoor.com/partner/jobListing.h...
#
# 0                                             salary  \
# 1  {'average_base_estimate': '$57,000 /yr (est.)'...
# 2  {'average_base_estimate': '$95.00 /hr (est.)',...
# 3
# 4  {'average_base_estimate': '$73,868 /yr (est.)'...
# 5  {'average_base_estimate': '$73,394 /yr (est.)'...
#
# 0                                            company  \
# 1  {'headquarter': 'Honolulu, HI', 'size': '201 t...
# 2
# 3  {'headquarter': 'New York, NY', 'size': 'Unkno...
# 4  {'headquarter': 'Pleasant Prairie, WI', 'size'...
# 5  {'headquarter': 'Cleveland, OH', 'size': '1000...
#
# 0                                            ratings  \
# 1  {'overall_rating': '2.9', 'recommend_company':...
# 2
# 3  {'overall_rating': '3.6', 'recommend_company':...
# 4  {'overall_rating': '3.4', 'recommend_company':...
# 5  {'overall_rating': '3.7', 'recommend_company':...
#
# 0                                            reviews  \
# 1  {'pros': 'Pros\nNo Pros have been reported by ...
# 2
# 3  {'pros': 'Pros\n"Good benefits and able to mov...
# 4  {'pros': 'Pros\n"Good benefits Good team Growi...
# 5  {'pros': 'Pros\n"good pay and benefits from da...
#
# 0                                      why-work-here  \
# 1
# 2
# 3
# 4  {'Culture': '', 'Warehouse': '', 'Sales': '', ...
# 5
#
# 0                                           benefits
# 1
# 2
# 3
# 4  {'rating': '4.4', 'rating_count': '', 'employe...
# 5

# %% [markdown]
# # Clean Data

# %%
import json

## General
def json_string_to_json(value):
    try:
        if type(value) == str:
            jsonVal = json.loads(value.replace('"','').replace("'",'"'))
            return jsonVal
        else:
            return value
    except:
        return None

def get_json_value(x, value):
    try:
        return x[value]
    except:
        return None
    
def expand_json(column_name):
    # Get Keys for Json
    variable_keys = list(job_cleaning[job_cleaning[column_name].notnull()][column_name].iloc[0].keys())
    
    # Break Json variables into Columns
    for key in variable_keys:
        job_cleaning[key] = job_cleaning[column_name].apply(lambda x: get_json_value(x, key))
        
        
## Salary
def clean_base_salary_figure(x):
    if x:
        return float(x.split(' ')[0].replace('$','').replace(',',''))
    else:
        return None
    
def clean_base_salary_type(x):
    if x:
        return x.split(' ')[1]
    else:
        return None

# %%
# 
job_cleaning = job_df.copy()

# Columns in 
json_columns = ['salary','company','ratings','reviews','why-work-here','benefits']

# Json-Strings to Json
for column in json_columns:
    # Json-Columns to Json
    job_cleaning[column] = job_cleaning[column].apply(lambda x: json_string_to_json(x))
    
    # Json Variables to Individual Columns
    expand_json(column)
    
# Remove Misc Columns
misc_columns=['Culture','Warehouse','Sales','Technology','Service/Support']
job_cleaning = job_cleaning[[x for x in job_cleaning.columns if x not in misc_columns]]


# Clean Salary
job_cleaning['salary_rate'] = job_cleaning['average_base_estimate'].apply(lambda x: clean_base_salary_figure(x))
job_cleaning['salary_type'] = job_cleaning['average_base_estimate'].apply(lambda x: clean_base_salary_type(x))

print('Salary Raw:\n{}\n'.format(job_cleaning['salary'][1]))
print('Rate: {}'.format(job_cleaning['salary_rate'][1]))
print('Type: {}'.format(job_cleaning['salary_type'][1]))
# Out:
# Salary Raw:
# {'average_base_estimate': '$57,000 /yr (est.)', 'base_range_min': '$50K ', 'base_range_max': '$64K', 'area_summary_url': ''}
#
# Rate: 57000.0
# Type: /yr

# %% [markdown]
# # Explore Data

# %%
# 
job_details_columns = ['company_name','job_title']
job_cleaning.head(2)
# Out:
# 0 company_name                                job_title  \
# 1    AlohaCare                             Data Analyst
# 2    Sidekicks  Board Certified Behavior Analyst (BCBA)
#
# 0                                           job_link              location  \
# 1  https://www.glassdoor.com/partner/jobListing.h...          Honolulu, HI
# 2  https://www.glassdoor.com/partner/jobListing.h...  Township of Hamilton
#
# 0                      salary_est  \
# 1     $50K - $64K (Employer est.)
# 2  $95.00 Per Hour(Employer est.)
#
# 0                                  short_description  \
# 1  Sciences, data analysis, accounting or related...
# 2  Conduct re-assessments and develop plans that ...
#
# 0                                       company_logo  \
# 1  https://media.glassdoor.com/sql/266409/alohaca...
# 2
#
# 0                             company_banner  \
# 1  /static/img/banners/default-ei-banner.jpg
# 2  /static/img/banners/default-ei-banner.jpg
#
# 0                                       company_link  \
# 1  https://www.glassdoor.com/Overview/Working-at-...
# 2
#
# 0                                        description  ... culture_and_values  \
# 1  The Company:\nAlohaCare is a local, non-profit...  ...                3.3
# 2  Looking to grow with an organization and be a ...  ...               None
#
# 0 senior_management                                               pros  \
# 1               2.8  Pros\nNo Pros have been reported by the Glassd...
# 2              None                                               None
#
# 0                                               cons rating rating_count  \
# 1  Cons\nZero training, zero support, passive agg...   None         None
# 2                                               None   None         None
#
# 0 employee_summary top_benefit_review_1 top_benefit_review_2  \
# 1             None                 None                 None
# 2             None                 None                 None
#
# 0 top_benefit_review_3
# 1                 None
# 2                 None
#
# [2 rows x 47 columns]

# %%
### Function for EDA (Exploratory Data Analysis)

# Plot Distribution
def plot_distribution(data,title='',column_x='', column_y=''):
    print('\nAverage {}: {}'.format(title, data.mean()))
    print('Count: {}'.format(data.count()))
    _ = plt.figure(figsize=(10,6))
    _ = plt.hist(data,bins=20)
    _ = plt.axvline(data.mean(), color='red')
    _ = plt.title(title,size=13)
    _ = plt.xlabel(column_x)
    _ = plt.ylabel(column_y)
    plt.show()
    
# Plot Bar Chart
def plot_barplot(data,x,y,title='',figsize=(8,10)):
    _ = plt.figure(figsize=figsize)
    _ = sns.barplot(x=x, y=y, data=data.head(20))
    _ = plt.title(title, size=15)

# Plot Pie Chart
def plot_pieplot(values,labels,title='',figsize=(8,10)):
    _ = plt.figure(figsize=figsize)
    _ = plt.pie(values, labels=labels, autopct='%.0f%%')
    _ = plt.title(title, size=15)

# %% [markdown]
# ## 1. Basic Info

# %% [markdown]
# ## 1a. Title

# %%
def generate_N_grams(text,ngram=1):
    text = text.lower().replace(' - ',' ').translate(str.maketrans('', '', string.punctuation))
    words=[word for word in text.split(" ") if word not in set(stopwords.words('english'))]  
    temp=zip(*[words[i:] for i in range(0,ngram)])
    ans=[' '.join(ngram) for ngram in temp]
    return ans

# %%
# Get n_grams from Job Titles
job_list = list(job_cleaning['job_title'].apply(lambda x: generate_N_grams(x,2)))
n_gram_2_jobs = [y for x in job_list for y in x]

# %%
# Get Value Counts
job_title_summary = pd.DataFrame(pd.Series(n_gram_2_jobs).value_counts())
job_title_summary = job_title_summary.reset_index()
job_title_summary.columns = ['job_title','count']

# Plot Titles
plot_barplot(job_title_summary,'count','job_title','Job Title Summary',figsize=(8,10))

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud(background_color='white').generate(' '.join(n_gram_2_jobs))

# Display the generated image:
_ = plt.figure(figsize=(12,10))
_ = plt.imshow(wordcloud, interpolation='bilinear')
_ = plt.axis("off")
_ = plt.show()

# %% [markdown]
# ## 2b. Work Location

# %%
# Work Locations
work_location_df = pd.DataFrame(job_cleaning['location'].value_counts()).reset_index()
work_location_df.columns = ['location','count']

# %%
# Plot Titles
plot_barplot(work_location_df,'count','location','Job Locations',figsize=(8,8))

# %% [markdown]
# ## 2. Salary

# %%
# Get Salary Cols
salary_columns = ['salary_rate','salary_type','salary','average_base_estimate','base_range_min','base_range_max','area_summary_url']

# Get Salary Data
salary_df = job_cleaning[job_details_columns + salary_columns]
salary_df.head(3)
# Out:
# 0                           company_name  \
# 1                              AlohaCare
# 2                              Sidekicks
# 3  Metropolitan Transportation Authority
#
# 0                                         job_title  salary_rate salary_type  \
# 1                                      Data Analyst      57000.0         /yr
# 2           Board Certified Behavior Analyst (BCBA)         95.0         /hr
# 3  Cybersecurity Analyst Levels 1-7, Data Scientist          NaN        None
#
# 0                                             salary average_base_estimate  \
# 1  {'average_base_estimate': '$57,000 /yr (est.)'...    $57,000 /yr (est.)
# 2  {'average_base_estimate': '$95.00 /hr (est.)',...     $95.00 /hr (est.)
# 3                                               None                  None
#
# 0 base_range_min base_range_max area_summary_url
# 1          $50K            $64K
# 2     $95.00 /hr         $95.00
# 3           None           None             None

# %%
# Salary Types 
salary_df.salary_type.value_counts()
# Out:
# /yr    331
# /hr     82
# /mo      3
# Name: salary_type, dtype: int64

# %%
# Separate by Type
yearly_jobs = salary_df[salary_df['salary_type'] == '/yr']
hourly_jobs = salary_df[salary_df['salary_type'] == '/hr']
monthly_jobs = salary_df[salary_df['salary_type'] == '/mo']

# Plot Salary Rates for Yearly jobs
plot_distribution(yearly_jobs['salary_rate'],'Salary Rate - Yearly Jobs','Count','Rate ($/yr)')

# Plot Salary Rates for Hourly jobs
plot_distribution(hourly_jobs['salary_rate'],'Salary Rate - Hourly Jobs','Count','Rate ($/hr)')

# Plot Salary Rates for Monthly jobs
plot_distribution(monthly_jobs['salary_rate'],'Salary Rate - Monthly Jobs','Count','Rate ($/yr)')
# Out:
# Average Salary Rate - Yearly Jobs: 75536.14803625377
# Count: 331
# Average Salary Rate - Hourly Jobs: 50.44609756097561
# Count: 82
# Average Salary Rate - Monthly Jobs: 6085.333333333333
# Count: 3

# %% [markdown]
# # 2. Company

# %%
# Get Company Cols
company_cols = ['headquarter','size','year_founded','type','industry','sector','revenue','website','company']

# Get Company Data
company_df = job_cleaning[job_details_columns + company_cols]
company_df.head(3)
# Out:
# 0                           company_name  \
# 1                              AlohaCare
# 2                              Sidekicks
# 3  Metropolitan Transportation Authority
#
# 0                                         job_title   headquarter  \
# 1                                      Data Analyst  Honolulu, HI
# 2           Board Certified Behavior Analyst (BCBA)          None
# 3  Cybersecurity Analyst Levels 1-7, Data Scientist  New York, NY
#
# 0                  size year_founded                    type  \
# 1  201 to 500 Employees         1994  Nonprofit Organization
# 2                  None         None                    None
# 3               Unknown                           Government
#
# 0                          industry                              sector  \
# 1  Health Care Services & Hospitals                          Healthcare
# 2                              None                                None
# 3         State & Regional Agencies  Government & Public Administration
#
# 0                   revenue                    website  \
# 1  Unknown / Non-Applicable  http://www.alohacare.org/
# 2                      None                       None
# 3  Unknown / Non-Applicable       http://www.mta.info/
#
# 0                                            company
# 1  {'headquarter': 'Honolulu, HI', 'size': '201 t...
# 2                                               None
# 3  {'headquarter': 'New York, NY', 'size': 'Unkno...

# %% [markdown]
# ## 2a. Company Sizes

# %%
#
sizes = ['1 to 50 Employees','51 to 200 Employees','201 to 500 Employees','501 to 1000 Employees','1001 to 5000 Employees','5001 to 10000 Employees','10000+ Employees','Unknown']
sizevalues = pd.DataFrame(job_cleaning['size'].value_counts()).T

#
company_sizes = sizevalues[sizes].T.reset_index()
company_sizes.columns = ['company_size','count']

# %%
company_sizes
# Out:
#               company_size  count
# 0        1 to 50 Employees     79
# 1      51 to 200 Employees     62
# 2     201 to 500 Employees     41
# 3    501 to 1000 Employees     46
# 4   1001 to 5000 Employees     84
# 5  5001 to 10000 Employees     31
# 6         10000+ Employees     99
# 7                  Unknown     40

# %%
# Plot Sizes
plot_barplot(company_sizes,'count','company_size','Company Size Counts',(7,6))

# %%
# Prep Variables
values = list(company_sizes['count'])
labels = list(company_sizes['company_size'])
values.reverse()
labels.reverse()

#
plot_pieplot(values, labels,'Company Size Pie', (12,8))
print('Not so Interesting... pretty evenly distributed')
# Out:
# Not so Interesting... pretty evenly distributed

# %% [markdown]
# ## 2b. Company Size Vs Salary

# %%
# 
sizeIndex = dict(zip(sizes, range(len(sizes))))

def add_index(x):
    if x != None:
        return sizeIndex[x]
    else:
        return None

# %%
# 
size_vs_salary = job_cleaning[job_cleaning['size'] != 'Unknown'][['size','salary_type','salary_rate']].copy()
size_vs_salary['order'] = size_vs_salary['size'].apply(lambda x: add_index(x))

# Types
size_yr = size_vs_salary[size_vs_salary['salary_type'] == '/yr']
size_hr = size_vs_salary[size_vs_salary['salary_type'] == '/hr']

# %%
# plot the Strip line
_ = plt.figure(figsize=(10,8))
_ = plt.xticks(rotation=45)
_ = plt.title('Company Size vs Salary (for Yearly)', size=14)
_ = plt.ylabel('Yearly Salary Rate ($USD)')
_ = sns.stripplot(
        data=size_yr.sort_values('order').dropna(), x="size", y="salary_rate",
        jitter=False, s=20, marker="D", linewidth=1, alpha=.1)
# plot the mean line
_ = sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            x="size",
            y="salary_rate",
            data=size_yr.sort_values('order').dropna(),
            showfliers=False,
            showbox=False,
            showcaps=False,
            ax=_)

# %%
# plot the Strip line
_ = plt.figure(figsize=(10,8))
_ = plt.xticks(rotation=45)
_ = plt.title('Company Size vs Salary (for Hourly)', size=14)
_ = plt.ylabel('Hourly Salary Rate ($USD)')
_ = sns.stripplot(
        data=size_hr.sort_values('order').dropna(), x="size", y="salary_rate",
        jitter=False, s=20, marker="D", linewidth=1, alpha=.1)
# plot the mean line
_ = sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            x="size",
            y="salary_rate",
            data=size_hr.sort_values('order').dropna(),
            showfliers=False,
            showbox=False,
            showcaps=False,
            ax=_)

# %% [markdown]
# ## 2c. Company Years

# %%
# 
company_years = company_df[(company_df['year_founded'].notnull()) & (company_df['year_founded'] != '')]

#
years = pd.DataFrame(company_years['year_founded'].value_counts()).reset_index()
years.columns = ['year_founded','count']

# %% [markdown]
# ### Year Founded

# %%
# Plot Year Founded
_ = plt.figure(figsize=(18,8))
_ = sns.lineplot(data=years.sort_values('year_founded'), x='year_founded',y='count')
_ = plt.xticks(list(years.sort_values('year_founded')['year_founded'])[::5], rotation=45)
_ = plt.title('Jobs by Year Founded')

# %%
# 
year_vs_salary = job_cleaning[['year_founded','salary_rate']].dropna()
year_vs_salary = year_vs_salary[year_vs_salary['year_founded'] != '']

# Column Values
year_vs_salary['salary_rate'] = year_vs_salary['salary_rate'].astype(int)
year_vs_salary['year_founded'] = year_vs_salary['year_founded'].astype(int)

# %% [markdown]
# ### Year Founded vs Salary
# No Correlation

# %%
# Plot Year Founded
_ = plt.figure(figsize=(12,8))
_ = sns.regplot(data=year_vs_salary, x='year_founded',y='salary_rate')
_ = plt.title('Year Founded vs Salary')

# %% [markdown]
# ## 2d. Organization Type

# %%
company_df.head(2)
# Out:
# 0 company_name                                job_title   headquarter  \
# 1    AlohaCare                             Data Analyst  Honolulu, HI
# 2    Sidekicks  Board Certified Behavior Analyst (BCBA)          None
#
# 0                  size year_founded                    type  \
# 1  201 to 500 Employees         1994  Nonprofit Organization
# 2                  None         None                    None
#
# 0                          industry      sector                   revenue  \
# 1  Health Care Services & Hospitals  Healthcare  Unknown / Non-Applicable
# 2                              None        None                      None
#
# 0                    website  \
# 1  http://www.alohacare.org/
# 2                       None
#
# 0                                            company
# 1  {'headquarter': 'Honolulu, HI', 'size': '201 t...
# 2                                               None

# %%
company_df.type.value_counts()
# Out:
# Company - Private                 247
# Company - Public                  126
# Nonprofit Organization             39
# College / University               19
# Government                         16
# Unknown                            10
# Hospital                            9
# Subsidiary or Business Segment      7
# Private Practice / Firm             4
# Contract                            3
# Franchise                           1
# School / School District            1
# Name: type, dtype: int64

# %% [markdown]
# ## Organization Type vs Salary

# %%
# 
type_vs_salary = job_cleaning[['type','salary_rate','salary_type']].copy().dropna()
type_vs_salary = type_vs_salary[type_vs_salary['type'] != '']

# Column Values
type_vs_salary['salary_rate'] = type_vs_salary['salary_rate'].astype(int)

# %%
# Types
type_vs_salary_yr = type_vs_salary[type_vs_salary['salary_type'] == '/yr']
type_vs_salary_hr = type_vs_salary[type_vs_salary['salary_type'] == '/hr']

# %%
# plot the Strip line
_ = plt.figure(figsize=(10,8))
_ = plt.xticks(rotation=45)
_ = plt.title('Organization Type vs Salary Rate (for Yearly)', size=14)
_ = plt.ylabel('Yearly Salary Rate ($USD)')
_ = sns.stripplot(
        data=type_vs_salary_yr, x="type", y="salary_rate",
        jitter=False, s=20, marker="D", linewidth=1, alpha=.1)
# plot the mean line
_ = sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            x="type",
            y="salary_rate",
            data=type_vs_salary_yr,
            showfliers=False,
            showbox=False,
            showcaps=False,
            ax=_)

# %%
# plot the Strip line
_ = plt.figure(figsize=(10,7))
_ = plt.xticks(rotation=45)
_ = plt.title('Organization Type vs Salary Rate (for Hourly)', size=14)
_ = plt.ylabel('Yearly Salary Rate ($USD)')
_ = sns.stripplot(
        data=type_vs_salary_hr, x="type", y="salary_rate",
        jitter=False, s=20, marker="D", linewidth=1, alpha=.1)
# plot the mean line
_ = sns.boxplot(showmeans=True,
            meanline=True,
            meanprops={'color': 'k', 'ls': '-', 'lw': 2},
            medianprops={'visible': False},
            whiskerprops={'visible': False},
            zorder=10,
            x="type",
            y="salary_rate",
            data=type_vs_salary_hr,
            showfliers=False,
            showbox=False,
            showcaps=False,
            ax=_)

# %% [markdown]
# ## 2e. Industry & Sector

# %%
company_df.head(2)
# Out:
# 0 company_name                                job_title   headquarter  \
# 1    AlohaCare                             Data Analyst  Honolulu, HI
# 2    Sidekicks  Board Certified Behavior Analyst (BCBA)          None
#
# 0                  size year_founded                    type  \
# 1  201 to 500 Employees         1994  Nonprofit Organization
# 2                  None         None                    None
#
# 0                          industry      sector                   revenue  \
# 1  Health Care Services & Hospitals  Healthcare  Unknown / Non-Applicable
# 2                              None        None                      None
#
# 0                    website  \
# 1  http://www.alohacare.org/
# 2                       None
#
# 0                                            company
# 1  {'headquarter': 'Honolulu, HI', 'size': '201 t...
# 2                                               None

# %% [markdown]
# ### Industry and Organization Type

# %%
#
industry_vs_organization = company_df.groupby(['type','industry']).count()[['job_title']].reset_index()

# %%
industry_vs_organization
# Out:
# 0                    type                                 industry  job_title
# 0    College / University                  Colleges & Universities         19
# 1       Company - Private                                                  42
# 2       Company - Private                         Accounting & Tax          8
# 3       Company - Private           Advertising & Public Relations         10
# 4       Company - Private                      Aerospace & Defense          2
# ..                    ...                                      ...        ...
# 112               Unknown                                                   6
# 113               Unknown                      Business Consulting          1
# 114               Unknown  Enterprise Software & Network Solutions          1
# 115               Unknown         Health Care Services & Hospitals          1
# 116               Unknown               Wood & Paper Manufacturing          1
#
# [117 rows x 3 columns]

# %% [markdown]
# # Rating

# %%
# Get Ratings Cols
ratings_cols = ['overall_rating', 'recommend_company', 'ceo_rating', 'ceo_name', 'ceo_rating_count', 'career_opportunities', 'comp_and_benefit', 'culture_and_values', 'senior_management','ratings']

# Get Ratings Data
ratings_df = job_cleaning[job_details_columns + ratings_cols]
ratings_df.head(3)

# %% [markdown]
# # Reviews

# %% [markdown]
# # Why Work Here

# %% [markdown]
# # Benefits

# %% [markdown]
# # Job Details

# %%
job_cleaning.iloc[0]
# Out:
# 0
# company_name                                                     AlohaCare
# job_title                                                     Data Analyst
# job_link                 https://www.glassdoor.com/partner/jobListing.h...
# location                                                      Honolulu, HI
# salary_est                                     $50K - $64K (Employer est.)
# short_description        Sciences, data analysis, accounting or related...
# company_logo             https://media.glassdoor.com/sql/266409/alohaca...
# company_banner                   /static/img/banners/default-ei-banner.jpg
# company_link             https://www.glassdoor.com/Overview/Working-at-...
# description              The Company:\nAlohaCare is a local, non-profit...
# job_id                                                       1008415699298
# external_url             https://www.glassdoor.com/partner/jobListing.h...
# salary                   {'average_base_estimate': '$57,000 /yr (est.)'...
# company                  {'headquarter': 'Honolulu, HI', 'size': '201 t...
# ratings                  {'overall_rating': '2.9', 'recommend_company':...
# reviews                  {'pros': 'Pros
# No Pros have been reported by t...
# why-work-here                                                         None
# benefits                                                              None
# average_base_estimate                                   $57,000 /yr (est.)
# base_range_min                                                       $50K
# base_range_max                                                        $64K
# area_summary_url
# headquarter                                                   Honolulu, HI
# size                                                  201 to 500 Employees
# year_founded                                                          1994
# type                                                Nonprofit Organization
# industry                                  Health Care Services & Hospitals
# sector                                                          Healthcare
# revenue                                           Unknown / Non-Applicable
# website                                          http://www.alohacare.org/
# overall_rating                                                         2.9
# recommend_company                                                     58 %
# ceo_rating                                                            54 %
# ceo_name                                          Francoise Culley-Trotman
# ceo_rating_count                                                 6 Ratings
# career_opportunities                                                   2.8
# comp_and_benefit                                                       2.7
# culture_and_values                                                     3.3
# senior_management                                                      2.8
# pros                     Pros\nNo Pros have been reported by the Glassd...
# cons                     Cons\nZero training, zero support, passive agg...
# rating                                                                None
# rating_count                                                          None
# employee_summary                                                      None
# top_benefit_review_1                                                  None
# top_benefit_review_2                                                  None
# top_benefit_review_3                                                  None
# Name: 1, dtype: object
